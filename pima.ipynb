# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import matplotlib.pyplot as pltp
import seaborn as sns

# %%
data=pd.read_csv('diabetes.csv')
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data.shape       #dimension of the dataset
# Out:
# (768, 9)

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# There is no null values in the data set

# %%
#correlation
data.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
len(data["Outcome"])
# Out:
# 768

# %%
from sklearn.model_selection import train_test_split

# %%
#Train Test
regressors=["Pregnancies","Glucose","BloodPressure","SkinThickness","Insulin","BMI","DiabetesPedigreeFunction","Age"]
response =["Outcome"]

# %%
X=data[regressors].values
y=data[response].values
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.30,random_state=10)

# %%
print(len(data.loc[data["Pregnancies"]==0]))
print(len(data.loc[data["Glucose"]==0]))
print(len(data.loc[data["BloodPressure"]==0]))
print(len(data.loc[data["SkinThickness"]==0]))
print(len(data.loc[data["Insulin"]==0]))
# Out:
# 111
# 5
# 35
# 227
# 374

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
newdata2=data.drop("Outcome",1).mask(data==0).fillna(data.mean())
newdata2
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0       6.000000    148.0           72.0      35.000000   79.799479  33.6
# 1       1.000000     85.0           66.0      29.000000   79.799479  26.6
# 2       8.000000    183.0           64.0      20.536458   79.799479  23.3
# 3       1.000000     89.0           66.0      23.000000   94.000000  28.1
# 4       3.845052    137.0           40.0      35.000000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763    10.000000    101.0           76.0      48.000000  180.000000  32.9
# 764     2.000000    122.0           70.0      27.000000   79.799479  36.8
# 765     5.000000    121.0           72.0      23.000000  112.000000  26.2
# 766     1.000000    126.0           60.0      20.536458   79.799479  30.1
# 767     1.000000     93.0           70.0      31.000000   79.799479  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# ...

# %%
Outcome=data["Outcome"]
Outcome
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
newdata3=pd.concat([newdata2,Outcome],axis=1)
newdata3
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0       6.000000    148.0           72.0      35.000000   79.799479  33.6
# 1       1.000000     85.0           66.0      29.000000   79.799479  26.6
# 2       8.000000    183.0           64.0      20.536458   79.799479  23.3
# 3       1.000000     89.0           66.0      23.000000   94.000000  28.1
# 4       3.845052    137.0           40.0      35.000000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763    10.000000    101.0           76.0      48.000000  180.000000  32.9
# 764     2.000000    122.0           70.0      27.000000   79.799479  36.8
# 765     5.000000    121.0           72.0      23.000000  112.000000  26.2
# 766     1.000000    126.0           60.0      20.536458   79.799479  30.1
# 767     1.000000     93.0           70.0      31.000000   79.799479  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
newdata3.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
newdata3.head(50)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin        BMI  \
# 0      6.000000    148.0      72.000000      35.000000   79.799479  33.600000
# 1      1.000000     85.0      66.000000      29.000000   79.799479  26.600000
# 2      8.000000    183.0      64.000000      20.536458   79.799479  23.300000
# 3      1.000000     89.0      66.000000      23.000000   94.000000  28.100000
# 4      3.845052    137.0      40.000000      35.000000  168.000000  43.100000
# 5      5.000000    116.0      74.000000      20.536458   79.799479  25.600000
# 6      3.000000     78.0      50.000000      32.000000   88.000000  31.000000
# 7     10.000000    115.0      69.105469      20.536458   79.799479  35.300000
# 8      2.000000    197.0      70.000000      45.000000  543.000000  30.500000
# 9      8.000000    125.0      96.000000      20.536458   79.799479  31.992578
# 10     4.000000    110.0      92.000000      20.536458   79.799479  37.600000
# ...

# %%
regressors=["Pregnancies","Glucose","BloodPressure","SkinThickness","Insulin","BMI","DiabetesPedigreeFunction","Age"]
response =["Outcome"]
X=newdata3[regressors].values
y=newdata3[response].values
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.30,random_state=10)

# %%
print(len(X_test))
print(len(X_train))
# Out:
# 231
# 537

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmod= LogisticRegression()
logmod.fit(X_train,y_train)
# Out:
# C:\Users\Raagu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\Raagu\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# y_pred=logmod.predict(X_test)
# y_pred

# %%
print("Accuracy",(logmod.score(X_test,y_test))) #Accuracy 74%
# Out:
# Accuracy 0.7402597402597403

# %%
from sklearn.metrics import confusion_matrix
conf= print(confusion_matrix(y_test,y_pred))

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
Decimod=DecisionTreeClassifier(max_leaf_nodes=10,random_state=0)
Decimod.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_leaf_nodes=10, random_state=0)

# %%
y_predi= Decimod.predict(X_test)

# %%
Decimod.score(X_test,y_test) #Accuracy 74.5%
# Out:
# 0.7445887445887446

# %%
from sklearn.metrics import confusion_matrix

# %%
confma=print(confusion_matrix(y_test,y_predi))
# Out:
# [[126  18]
#  [ 41  46]]
